# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 15   |  |
# | :-------------|:-------------|
# | Christoph Smit| 6494056 |
# | Rune Veraart | 6439748 |
# | Jan van de Poll| 6527590|

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 15     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 1100-1145 | Jan |
# | ontwerp-eis berekenen| 1100-1145 | Rune / Christoph|
# | Groepsoverleg | 1145-1200 | hele groep |
# | Simulatie / evaluatie| 1200-1230 | hele groep |
# | simulatie af | 1230 | ---|
# | Onywerp af | 1630 | ---|
# | Pauze 1| 1230-1330 | hele groep |
# | Pauze 2| 1415-1430 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 2 |
# | hoe lang voor één meting | 30s |
# | verwacht nauwkeurigheid meting | $\pm 0.01$ op de amplitude |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
g = 9.81

omega_0 = np.sqrt(5**2/4)*2*np.pi
def verhouding_amplitude(omega):
    return 1 / (1-omega**2/omega_0**2)

def d_x(omega_0):
    return g/omega_0**2

# %%
x_test = np.linspace(0.001, 1000, 10000)
dx_test = np.linspace(1, 10, 100)
plt.figure()
plt.loglog(x_test, np.abs(verhouding_amplitude(x_test)))
plt.xlim(1, 1000)
plt.ylim(0.01, 1000)
plt.xlabel("omega")
plt.ylabel("verhouding amplitude")

plt.figure()
plt.plot(dx_test, d_x(dx_test))
plt.xlabel("omega_0")
plt.ylabel("delta_x")
# Out:
# Text(0, 0.5, 'delta_x')

# %%
omega_0 = np.sqrt(5**2/4)*2*np.pi
print("omega_0 =", omega_0, "rad/s")

print("verhouding_amplitude =", 1/(1-(10*np.pi)**2/omega_0**2))

delta_x = g/(omega_0**2)

print("delta_x =", delta_x, "m")
# Out:
# omega_0 = 15.707963267948966 rad/s
# verhouding_amplitude = -0.3333333333333333
# delta_x = 0.039758432461253344 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
def veerconstante(m, d_x):
    return m*g/d_x

m_test = np.linspace(0.1, 5, 1000)
plt.figure()
plt.plot(m_test, veerconstante(m_test, delta_x), label = f"delta_x = {delta_x:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*2), label = f"delta_x = {delta_x*2:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*5), label = f"delta_x = {delta_x*5:.2f} m")
plt.xlabel("massa(kg)")
plt.ylabel("veerconstante(N/m)")
plt.ylim(0,200)
plt.xlim(0, 2)
plt.legend()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - veerconstante verlagen
# - massa verhogen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 16 cm

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Schets2.jpg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
# 16 cm
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Nee, we halen 21 cm
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# 22 cm
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Ja het is genoeg om te kunnen meten
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.
omega_2 = np.sqrt(9.81/0.21)

def verhouding_amplitude2(omega):
    return 1 / (1-omega**2/omega_2**2)

plt.figure()
plt.loglog(x_test, np.abs(verhouding_amplitude(x_test)), label = "eerste grafiek")
plt.loglog(x_test, np.abs(verhouding_amplitude2(x_test)), label = "grafiek met delta_x = 0.21 m")
plt.xlim(1, 1000)
plt.ylim(0.01, 1000)
plt.xlabel("omega")
plt.ylabel("verhouding amplitude")
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.

radiale = np.array([5.5, 6, 1, 9, 0.1, 3, 2, 1.5])*2*np.pi
u_radiale = np.array([5.6, 6.1, 1.1, 9.1, 0.11, 3.1, 2.1, 1.51])*2*np.pi
u_rad = np.abs(radiale - u_radiale)
verhouding = np.array([0.2/2.3, 0.25/3, 2/0.5, 0.3 / 5, 1, 0.3/1.5, 0.6/1.1, 0.9/0.5])
u_verhouding = np.array([0.1/2.4, 0.15/3.1, 1.9/0.6, 0.2 / 5.1, 0.9/1.1, 0.2/1.6, 0.5/1.2, 0.8/0.6])
u_ver = np.abs(verhouding - u_verhouding)
plt.figure()
plt.plot(x_test, np.abs(verhouding_amplitude(x_test)), label = "eerste grafiek")
plt.plot(x_test, np.abs(verhouding_amplitude2(x_test)), label = "grafiek met delta_x = 0.21 m")
plt.plot(radiale, verhouding, "k.", label = "gemeten punten")
plt.errorbar(radiale, verhouding, xerr=u_rad, yerr=u_ver, fmt='none', label='fouten')
plt.xlim(0.1, 1000)
plt.xscale("log")
plt.yscale("log")
plt.ylim(0.01, 1000)
plt.xlabel("omega(rad/s)")
plt.ylabel("verhouding amplitude")
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# Leerdoel 1(Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen.):

# %%
def veerconstante(m, d_x):
    return m*g/d_x

m_test = np.linspace(0.1, 5, 1000)
plt.figure()
plt.plot(m_test, veerconstante(m_test, delta_x), label = f"delta_x = {delta_x:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*2), label = f"delta_x = {delta_x*2:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*5), label = f"delta_x = {delta_x*5:.2f} m")
plt.xlabel("massa(kg)")
plt.ylabel("veerconstante(N/m)")
plt.ylim(0,200)
plt.xlim(0, 2)
plt.legend()

# %%
x_test = np.linspace(0.001, 1000, 10000)
dx_test = np.linspace(1, 10, 100)
plt.figure()
plt.loglog(x_test, np.abs(verhouding_amplitude(x_test)))
plt.xlim(1, 1000)
plt.ylim(0.01, 1000)
plt.xlabel("omega")
plt.ylabel("verhouding amplitude")

plt.figure()
plt.plot(dx_test, d_x(dx_test))
plt.xlabel("omega_0")
plt.ylabel("delta_x")
# Out:
# Text(0, 0.5, 'delta_x')

# %%
omega_0 = np.sqrt(5**2/4)*2*np.pi
print("omega_0 =", omega_0, "rad/s")

print("verhouding_amplitude =", 1/(1-(10*np.pi)**2/omega_0**2))

delta_x = g/(omega_0**2)

print("delta_x =", delta_x, "m")
# Out:
# omega_0 = 15.707963267948966 rad/s
# verhouding_amplitude = -0.3333333333333333
# delta_x = 0.039758432461253344 m

# %% [markdown]
# Leerdoel 2(Op basis van een differentiaal vergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp):

# %%
def veerconstante(m, d_x):
    return m*g/d_x

m_test = np.linspace(0.1, 5, 1000)
plt.figure()
plt.plot(m_test, veerconstante(m_test, delta_x), label = f"delta_x = {delta_x:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*2), label = f"delta_x = {delta_x*2:.2f} m")
plt.plot(m_test, veerconstante(m_test, delta_x*5), label = f"delta_x = {delta_x*5:.2f} m")
plt.xlabel("massa(kg)")
plt.ylabel("veerconstante(N/m)")
plt.ylim(0,200)
plt.xlim(0, 2)
plt.legend()

# %% [markdown]
# ##### schets opstelling:
# <img src="Schets2.jpg" width="400">

# %%
# De plot met onze data, vergeleken met de verwachtte data

radiale = np.array([5.5, 6, 1, 9, 0.1, 3, 2, 1.5])*2*np.pi
u_radiale = np.array([5.6, 6.1, 1.1, 9.1, 0.11, 3.1, 2.1, 1.51])*2*np.pi
u_rad = np.abs(radiale - u_radiale)
verhouding = np.array([0.2/2.3, 0.25/3, 2/0.5, 0.3 / 5, 1, 0.3/1.5, 0.6/1.1, 0.9/0.5])
u_verhouding = np.array([0.1/2.4, 0.15/3.1, 1.9/0.6, 0.2 / 5.1, 0.9/1.1, 0.2/1.6, 0.5/1.2, 0.8/0.6])
u_ver = np.abs(verhouding - u_verhouding)
plt.figure()
plt.plot(x_test, np.abs(verhouding_amplitude2(x_test)),'orangered', label = "grafiek met delta_x = 0.21 m")
plt.plot(radiale, verhouding, "k.", label = "gemeten punten")
plt.errorbar(radiale, verhouding, xerr=u_rad, yerr=u_ver, fmt='none', label='fouten')
plt.xlim(0.1, 100)
plt.xscale("log")
plt.yscale("log")
plt.ylim(0.01, 100)
plt.xlabel("omega(rad/s)")
plt.ylabel("verhouding amplitude")
plt.legend()
plt.show()

# %%
omega_0 = np.sqrt(5**2/4)*2*np.pi
print("omega_0 =", omega_0, "rad/s")

print("verhouding_amplitude =", 1/(1-(10*np.pi)**2/omega_0**2))

delta_x = g/(omega_0**2)

print("delta_x =", delta_x, "m")
# Out:
# omega_0 = 15.707963267948966 rad/s
# verhouding_amplitude = -0.3333333333333333
# delta_x = 0.039758432461253344 m

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
# 16 cm
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Nee, we halen 21 cm
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# 22 cm
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Ja het is genoeg om te kunnen meten
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.
